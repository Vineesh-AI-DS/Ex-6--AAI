# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
f = open("/content/samplefile.txt", "r")

# %%
sentences = f.readlines()
sentences
f.close()

# %%
verbs = [[] for _ in sentences]
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)

  # Tokenize the sentence into words
  words = word_tokenize(sentence)

  # Identify the parts of speech for each word
  pos_tags = nltk.pos_tag(words)

  # Print the parts of speech
  for word,tag in pos_tags:
    print(word,"->",tag)

    # Save verbs
    if tag.startswith('VB'):
      verbs[i].append(word)
  i+=1
  print("\n\n")
# Out:
# Sentence 1 : The curious dog chased the red ball through the park.
#
# The -> DT
# curious -> JJ
# dog -> NN
# chased -> VBD
# the -> DT
# red -> JJ
# ball -> NN
# through -> IN
# the -> DT
# park -> NN
# . -> .
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# Sarah -> NNP
# enjoys -> VBZ
# baking -> VBG
# delicious -> JJ
# chocolate -> NN
# chip -> NN
# cookies -> NNS
# on -> IN
# weekends -> NNS
# . -> .
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# Artificial -> JJ
# intelligence -> NN
# is -> VBZ
# rapidly -> RB
# transforming -> VBG
# many -> JJ
# industries -> NNS
# . -> .
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# Despite -> IN
# the -> DT
# rain -> NN
# , -> ,
# the -> DT
# children -> NNS
# played -> VBD
# happily -> RB
# in -> IN
# puddles -> NNS
# . -> .
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# This -> DT
# new -> JJ
# book -> NN
# explores -> VBZ
# the -> DT
# history -> NN
# of -> IN
# ancient -> JJ
# civilizations -> NNS
# . -> .
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# The -> DT
# concert -> NN
# was -> VBD
# a -> DT
# huge -> JJ
# success -> NN
# , -> ,
# with -> IN
# thousands -> NNS
# of -> IN
# fans -> NNS
# in -> IN
# attendance -> NN
# . -> .
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# John -> NNP
# decided -> VBD
# to -> TO
# learn -> VB
# a -> DT
# new -> JJ
# language -> NN
# this -> DT
# year -> NN
# . -> .
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# Medical -> JJ
# research -> NN
# is -> VBZ
# constantly -> RB
# striving -> VBG
# to -> TO
# find -> VB
# cures -> NNS
# for -> IN
# diseases -> NNS
# . -> .
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# The -> DT
# aroma -> NN
# of -> IN
# freshly -> JJ
# brewed -> VBN
# coffee -> NN
# filled -> VBD
# the -> DT
# air -> NN
# . -> .
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# plastic -> NN
# bottles -> NNS
# helps -> VBZ
# to -> TO
# conserve -> VB
# natural -> JJ
# resources -> NNS
# . -> .
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# The -> DT
# majestic -> JJ
# mountains -> NNS
# stood -> VBD
# tall -> JJ
# against -> IN
# the -> DT
# clear -> JJ
# blue -> NN
# sky -> NN
# . -> .
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# The -> DT
# library -> NN
# is -> VBZ
# a -> DT
# treasure -> NN
# trove -> NN
# of -> IN
# knowledge -> NN
# waiting -> VBG
# to -> TO
# be -> VB
# explored -> VBN
# . -> .
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# a -> DT
# walk -> NN
# in -> IN
# nature -> NN
# is -> VBZ
# a -> DT
# great -> JJ
# way -> NN
# to -> TO
# relax -> VB
# and -> CC
# de-stress -> NN
# . -> .
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# Many -> JJ
# people -> NNS
# enjoy -> VBP
# traveling -> VBG
# to -> TO
# new -> JJ
# and -> CC
# exciting -> JJ
# destinations -> NNS
# . -> .
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# Technology -> NN
# has -> VBZ
# made -> VBN
# communication -> NN
# much -> JJ
# faster -> JJR
# and -> CC
# easier -> JJR
# . -> .
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
#
# Learning -> VBG
# to -> TO
# play -> VB
# a -> DT
# musical -> JJ
# instrument -> NN
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# endangered -> VBN
# species -> NNS
# is -> VBZ
# crucial -> JJ
# for -> IN
# maintaining -> VBG
# biodiversity -> NN
# . -> .
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# The -> DT
# internet -> NN
# has -> VBZ
# revolutionized -> VBN
# the -> DT
# way -> NN
# we -> PRP
# access -> NN
# information -> NN
# . -> .
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# Astronomy -> NNP
# allows -> VBZ
# us -> PRP
# to -> TO
# study -> VB
# the -> DT
# vast -> JJ
# universe -> JJ
# beyond -> IN
# our -> PRP$
# planet -> NN
# . -> .
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# Ecotourism -> NN
# promotes -> VBZ
# sustainable -> JJ
# travel -> NN
# practices -> NNS
# . -> .
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# A -> DT
# healthy -> JJ
# diet -> NN
# is -> VBZ
# essential -> JJ
# for -> IN
# maintaining -> VBG
# good -> JJ
# physical -> JJ
# health -> NN
# . -> .
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# Building -> NN
# strong -> JJ
# relationships -> NNS
# with -> IN
# others -> NNS
# is -> VBZ
# important -> JJ
# for -> IN
# emotional -> JJ
# well-being -> NN
# . -> .
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# Climate -> NNP
# change -> NN
# is -> VBZ
# a -> DT
# major -> JJ
# challenge -> NN
# facing -> VBG
# our -> PRP$
# planet -> NN
# today -> NN
# . -> .
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# Renewable -> JJ
# energy -> NN
# sources -> NNS
# like -> IN
# solar -> JJ
# and -> CC
# wind -> JJ
# power -> NN
# are -> VBP
# becoming -> VBG
# increasingly -> RB
# popular -> JJ
# . -> .
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# Space -> NNP
# exploration -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# learn -> VB
# more -> JJR
# about -> IN
# the -> DT
# origins -> NNS
# of -> IN
# our -> PRP$
# universe -> NN
# . -> .
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# your -> PRP$
# time -> NN
# to -> TO
# help -> VB
# others -> NNS
# can -> MD
# be -> VB
# a -> DT
# rewarding -> JJ
# experience -> NN
# . -> .
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# Critical -> JJ
# thinking -> NN
# skills -> NNS
# are -> VBP
# essential -> JJ
# for -> IN
# success -> NN
# in -> IN
# today -> NN
# 's -> POS
# world -> NN
# . -> .
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# The -> DT
# power -> NN
# of -> IN
# imagination -> NN
# allows -> VBZ
# us -> PRP
# to -> TO
# create -> VB
# and -> CC
# innovate -> VB
# . -> .
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# a -> DT
# strong -> JJ
# work -> NN
# ethic -> NN
# is -> VBZ
# important -> JJ
# for -> IN
# achieving -> VBG
# your -> PRP$
# goals -> NNS
# . -> .
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# Education -> NN
# is -> VBZ
# the -> DT
# key -> NN
# to -> TO
# unlocking -> VB
# your -> PRP$
# full -> JJ
# potential -> NN
# . -> .

# %%
# Identify synonyms and antonyms for each word
print("Synonyms and Antonymns for verbs in each sentence:\n")
i=0
for sentence in sentences:
  print("Sentence",i+1,":", sentence)
  pos_tags = nltk.pos_tag(verbs[i])
  for word,tag in pos_tags:
    print(word,"->",tag)
    synonyms = []
    antonyms = []
    for syn in wordnet.synsets(word):
      for lemma in syn.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
          for antonym in lemma.antonyms():
            antonyms.append(antonym.name())

    # Print the synonyms and antonyms
    print("Synonyms:",set(synonyms))
    print("Antonyms:", set(antonyms) if antonyms else "None")
    print()
  print("\n\n")
  i+=1
# Out:
# Synonyms and Antonymns for verbs in each sentence:
#
# Sentence 1 : The curious dog chased the red ball through the park.
#
# chased -> VBN
# Synonyms: {'chased', 'furrow', 'tail', 'chase', 'tag', 'trail', 'go_after', 'chase_after', 'dog', 'track', 'chamfer', 'give_chase', 'pursued'}
# Antonyms: None
#
#
#
#
# Sentence 2 : Sarah enjoys baking delicious chocolate chip cookies on weekends.
#
# enjoys -> NNS
# Synonyms: {'relish', 'savour', 'enjoy', 'revel', 'delight', 'bask', 'love', 'savor'}
# Antonyms: {'suffer'}
#
# baking -> VBG
# Synonyms: {'baking_hot', 'bake', 'baking', 'broil'}
# Antonyms: None
#
#
#
#
# Sentence 3 : Artificial intelligence is rapidly transforming many industries.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# transforming -> VBG
# Synonyms: {'metamorphose', 'translate', 'transform', 'transmute', 'transubstantiate'}
# Antonyms: None
#
#
#
#
# Sentence 4 : Despite the rain, the children played happily in puddles.
#
# played -> NNS
# Synonyms: {'take_on', 'bring', 'act_as', 'act', 'spiel', 'trifle', 'diddle', 'recreate', 'bet', 'make_for', 'roleplay', 'flirt', 'dally', 'play', 'encounter', 'meet', 'wreak', 'represent', 'toy', 'fiddle', 'played', 'wager', 'playact', 'run', 'work'}
# Antonyms: None
#
#
#
#
# Sentence 5 : This new book explores the history of ancient civilizations.
#
# explores -> NNS
# Synonyms: {'explore', 'research', 'search'}
# Antonyms: None
#
#
#
#
# Sentence 6 : The concert was a huge success, with thousands of fans in attendance.
#
# was -> VBD
# Synonyms: {'cost', 'WA', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'Washington', 'equal', 'be', 'exist', 'Evergreen_State', 'live', 'represent'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 7 : John decided to learn a new language this year.
#
# decided -> VBD
# Synonyms: {'adjudicate', 'determine', 'settle', 'resolve', 'decide', 'distinct', "make_up_one's_mind", 'decided'}
# Antonyms: None
#
# learn -> NN
# Synonyms: {'take', 'acquire', 'con', 'get_wind', 'memorise', 'read', 'see', 'discover', 'instruct', 'teach', 'study', 'find_out', 'check', 'get_a_line', 'determine', 'learn', 'watch', 'hear', 'pick_up', 'ascertain', 'memorize', 'larn', 'get_word'}
# Antonyms: None
#
#
#
#
# Sentence 8 : Medical research is constantly striving to find cures for diseases.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# striving -> VBG
# Synonyms: {'nisus', 'pains', 'strive', 'endeavor', 'reach', 'strain', 'endeavour', 'striving'}
# Antonyms: None
#
# find -> VB
# Synonyms: {'line_up', 'notice', 'uncovering', 'chance', 'rule', 'incur', 'find_oneself', 'see', 'discover', 'find', 'feel', 'witness', 'receive', 'find_out', 'discovery', 'recover', 'breakthrough', 'determine', 'get_hold', 'come_up', 'retrieve', 'encounter', 'happen', 'observe', 'detect', 'ascertain', 'bump', 'get', 'regain', 'obtain'}
# Antonyms: {'lose'}
#
#
#
#
# Sentence 9 : The aroma of freshly brewed coffee filled the air.
#
# brewed -> VBN
# Synonyms: {'brew'}
# Antonyms: None
#
# filled -> VBD
# Synonyms: {'satiate', 'occupy', 'fulfill', 'take', 'fill', 'satisfy', 'make_full', 'filled', 'fulfil', 'replete', 'meet', 'fill_up', 'sate'}
# Antonyms: {'empty', 'unfilled'}
#
#
#
#
# Sentence 10 : Recycling plastic bottles helps to conserve natural resources.
#
# Recycling -> VBG
# Synonyms: {'reprocess', 'recycling', 'reuse', 'recycle'}
# Antonyms: None
#
# helps -> VBZ
# Synonyms: {'help_oneself', 'helper', 'avail', 'supporter', 'help', 'assistance', 'serve', 'facilitate', 'service', 'assist', 'aid', 'assistant'}
# Antonyms: None
#
# conserve -> VB
# Synonyms: {'conserves', 'keep_up', 'economize', 'conserve', 'economise', 'preserve', 'maintain', 'preserves', 'husband'}
# Antonyms: {'waste'}
#
#
#
#
# Sentence 11 : The majestic mountains stood tall against the clear blue sky.
#
# stood -> NN
# Synonyms: {'suffer', 'resist', 'digest', 'stomach', 'tolerate', 'bear', 'place_upright', 'stick_out', 'support', 'endure', 'stand_up', 'abide', 'brook', 'stand', 'fend', 'put_up', 'remain_firm'}
# Antonyms: {'lie', 'sit', 'yield'}
#
#
#
#
# Sentence 12 : The library is a treasure trove of knowledge waiting to be explored.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# waiting -> VBG
# Synonyms: {'look', 'waitress', 'wait', 'await', 'ready_and_waiting', 'waiting', 'hold_back', 'expect', 'hold_off'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'cost', 'constitute', 'glucinium', 'atomic_number_4', 'beryllium', 'comprise', 'make_up', 'follow', 'embody', 'personify', 'equal', 'be', 'exist', 'live', 'Be', 'represent'}
# Antonyms: {'differ'}
#
# explored -> VBN
# Synonyms: {'explore', 'research', 'search'}
# Antonyms: None
#
#
#
#
# Sentence 13 : Taking a walk in nature is a great way to relax and de-stress.
#
# Taking -> VBG
# Synonyms: {'consume', 'take_on', 'take', 'bring', 'involve', 'subscribe', 'acquire', 'adopt', 'carry', 'ingest', 'choose', 'train', 'take_aim', 'hold', 'postulate', 'consider', 'have', 'strike', 'lead', 'read', 'call_for', 'pack', 'demand', 'pickings', 'necessitate', 'require', 'admit', 'pick_out', 'use_up', 'need', 'direct', 'study', 'conduct', 'remove', 'occupy', 'charter', 'learn', 'take_away', 'rent', 'fetching', 'taking', 'shoot', 'make', 'take_in', 'assume', 'select', 'exact', 'subscribe_to', 'ask', 'convey', 'aim', 'get', 'guide', 'engage', 'accept', 'film', 'withdraw', 'take_up', 'contract', 'drive', 'fill', 'hire', 'claim', 'lease', 'contain', 'winning', 'get_hold_of', 'submit', 'look_at', 'deal'}
# Antonyms: {'abstain', 'refuse', 'disclaim', 'give', 'obviate'}
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# relax -> NN
# Synonyms: {'decompress', 'unstrain', 'unwind', 'slacken', 'slack', 'make_relaxed', 'unbend', 'loose', 'loosen_up', 'slack_up', 'unlax', 'loosen', 'relax', 'slow_down'}
# Antonyms: {'stiffen', 'strain', 'tense'}
#
#
#
#
# Sentence 14 : Many people enjoy traveling to new and exciting destinations.
#
# enjoy -> NN
# Synonyms: {'relish', 'savour', 'enjoy', 'revel', 'delight', 'bask', 'love', 'savor'}
# Antonyms: {'suffer'}
#
# traveling -> VBG
# Synonyms: {'journey', 'trip', 'move_around', 'travelling', 'move', 'travel', 'locomote', 'go', 'traveling', 'jaunt'}
# Antonyms: {'stay_in_place'}
#
#
#
#
# Sentence 15 : Technology has made communication much faster and easier.
#
# has -> VBZ
# Synonyms: {'consume', 'suffer', 'take', 'ingest', 'hour_angle', 'hold', 'HA', 'cause', 'have', 'bear', 'receive', 'possess', 'induce', 'feature', 'let', 'take_in', 'stimulate', 'give_birth', 'give', 'sustain', 'birth', 'get', 'accept', 'throw', 'experience', 'own', 'have_got', 'deliver', 'make'}
# Antonyms: {'lack', 'abstain', 'refuse'}
#
# made -> VBN
# Synonyms: {'defecate', 'form', 'score', 'build', 'establish', 'do', 'take', 'ca-ca', 'nominate', 'wee-wee', 'realize', 'make_up', 'stool', 'piss', 'hold', 'urinate', 'wee', 'take_a_crap', 'hit', 'cause', 'have', 'relieve_oneself', 'crap', 'made', 'micturate', 'get_to', 'take_a_shit', 'puddle', 'constitute', 'pretend', 'pee-pee', 'pass_water', 'cook', 'make_water', 'piddle', 'attain', 'induce', 'seduce', 'make_believe', 'ready', 'take_a_leak', 'progress_to', 'shit', 'gain', 'fix', 'spend_a_penny', 'stimulate', 'take_in', 'earn', 'realise', 'name', 'draw', 'arrive_at', 'give', 'get', 'produce', 'create', 'throw', 'bring_in', 'prepare', 'reach', 'construct', 'lay_down', 'pull_in', 'pee', 'make', 'clear', 'work'}
# Antonyms: {'unmake', 'unmade', 'break'}
#
#
#
#
# Sentence 16 : Learning to play a musical instrument can be a rewarding experience.
#
# Learning -> VBG
# Synonyms: {'take', 'acquire', 'con', 'get_wind', 'erudition', 'encyclopaedism', 'acquisition', 'learnedness', 'memorise', 'read', 'see', 'discover', 'eruditeness', 'instruct', 'teach', 'study', 'find_out', 'check', 'get_a_line', 'determine', 'learn', 'watch', 'hear', 'pick_up', 'learning', 'ascertain', 'memorize', 'scholarship', 'get_word', 'encyclopedism', 'larn'}
# Antonyms: None
#
# play -> NN
# Synonyms: {'sport', 'frolic', 'take_on', 'bring', 'act_as', 'manoeuvre', 'act', 'playing_period', 'looseness', 'spiel', 'trifle', 'turn', 'diddle', 'gambling', 'romp', 'shimmer', 'gaming', 'recreate', 'period_of_play', 'bet', 'make_for', 'roleplay', 'fun', 'bid', 'flirt', 'dally', 'play', 'encounter', 'meet', 'swordplay', 'gambol', 'wreak', 'represent', 'dramatic_play', 'toy', 'drama', 'fiddle', 'caper', "child's_play", 'wager', 'free_rein', 'maneuver', 'playact', 'run', 'work'}
# Antonyms: {'tightness'}
#
# be -> VB
# Synonyms: {'cost', 'constitute', 'glucinium', 'atomic_number_4', 'beryllium', 'comprise', 'make_up', 'follow', 'embody', 'personify', 'equal', 'be', 'exist', 'live', 'Be', 'represent'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 17 : Protecting endangered species is crucial for maintaining biodiversity.
#
# Protecting -> VBG
# Synonyms: {'protect', 'protecting'}
# Antonyms: None
#
# endangered -> VBN
# Synonyms: {'endanger', 'endangered', 'expose', 'peril', 'menace', 'queer', 'jeopardize', 'scupper', 'jeopardise', 'threaten', 'imperil'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'keep_up', 'keep', 'maintain', 'observe', 'exert', 'uphold', 'preserve', 'hold', 'defend', 'conserve', 'sustain', 'assert', 'asseverate', 'wield'}
# Antonyms: None
#
#
#
#
# Sentence 18 : The internet has revolutionized the way we access information.
#
# has -> VBZ
# Synonyms: {'consume', 'suffer', 'take', 'ingest', 'hour_angle', 'hold', 'HA', 'cause', 'have', 'bear', 'receive', 'possess', 'induce', 'feature', 'let', 'take_in', 'stimulate', 'give_birth', 'give', 'sustain', 'birth', 'get', 'accept', 'throw', 'experience', 'own', 'have_got', 'deliver', 'make'}
# Antonyms: {'lack', 'abstain', 'refuse'}
#
# revolutionized -> VBN
# Synonyms: {'inspire', 'revolutionize', 'overturn', 'revolutionise'}
# Antonyms: None
#
#
#
#
# Sentence 19 : Astronomy allows us to study the vast universe beyond our planet.
#
# allows -> NNS
# Synonyms: {'provide', 'reserve', 'tolerate', 'allow', 'leave', 'set_aside', 'appropriate', 'take_into_account', 'let', 'admit', 'permit', 'allow_for', 'countenance', 'give_up', 'earmark', 'grant'}
# Antonyms: {'deny', 'forbid', 'disallow', 'prevent'}
#
# study -> NN
# Synonyms: {'canvass', 'field_of_study', 'take', 'analyze', 'field', 'discipline', 'subject_field', 'hit_the_books', 'consider', 'cogitation', 'contemplate', 'read', 'meditate', 'bailiwick', 'written_report', 'report', 'examine', 'survey', 'canvas', 'study', 'sketch', 'learn', 'subject', 'subject_area', 'analyse', 'work'}
# Antonyms: None
#
#
#
#
# Sentence 20 : Ecotourism promotes sustainable travel practices.
#
# promotes -> NNS
# Synonyms: {'raise', 'further', 'promote', 'kick_upstairs', 'elevate', 'push', 'boost', 'advertize', 'advance', 'advertise', 'upgrade', 'encourage'}
# Antonyms: {'demote'}
#
#
#
#
# Sentence 21 : A healthy diet is essential for maintaining good physical health.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# maintaining -> VBG
# Synonyms: {'keep_up', 'keep', 'maintain', 'observe', 'exert', 'uphold', 'preserve', 'hold', 'defend', 'conserve', 'sustain', 'assert', 'asseverate', 'wield'}
# Antonyms: None
#
#
#
#
# Sentence 22 : Building strong relationships with others is important for emotional well-being.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 23 : Climate change is a major challenge facing our planet today.
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# facing -> VBG
# Synonyms: {'face_up', 'facing', 'present', 'look', 'veneer', 'lining', 'face', 'front', 'cladding', 'confront'}
# Antonyms: {'avoid', 'back'}
#
#
#
#
# Sentence 24 : Renewable energy sources like solar and wind power are becoming increasingly popular.
#
# are -> VBP
# Synonyms: {'ar', 'cost', 'are', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# becoming -> VBG
# Synonyms: {'decorous', 'becoming', 'comely', 'decent', 'suit', 'comme_il_faut', 'seemly', 'go', 'become', 'turn', 'get'}
# Antonyms: None
#
#
#
#
# Sentence 25 : Space exploration allows us to learn more about the origins of our universe.
#
# allows -> NNS
# Synonyms: {'provide', 'reserve', 'tolerate', 'allow', 'leave', 'set_aside', 'appropriate', 'take_into_account', 'let', 'admit', 'permit', 'allow_for', 'countenance', 'give_up', 'earmark', 'grant'}
# Antonyms: {'deny', 'forbid', 'disallow', 'prevent'}
#
# learn -> VBP
# Synonyms: {'take', 'acquire', 'con', 'get_wind', 'memorise', 'read', 'see', 'discover', 'instruct', 'teach', 'study', 'find_out', 'check', 'get_a_line', 'determine', 'learn', 'watch', 'hear', 'pick_up', 'ascertain', 'memorize', 'larn', 'get_word'}
# Antonyms: None
#
#
#
#
# Sentence 26 : Volunteering your time to help others can be a rewarding experience.
#
# Volunteering -> VBG
# Synonyms: {'volunteer', 'offer'}
# Antonyms: None
#
# help -> NN
# Synonyms: {'help_oneself', 'helper', 'avail', 'supporter', 'help', 'assistance', 'serve', 'facilitate', 'service', 'assist', 'aid', 'assistant'}
# Antonyms: None
#
# be -> VB
# Synonyms: {'cost', 'constitute', 'glucinium', 'atomic_number_4', 'beryllium', 'comprise', 'make_up', 'follow', 'embody', 'personify', 'equal', 'be', 'exist', 'live', 'Be', 'represent'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 27 : Critical thinking skills are essential for success in today's world.
#
# are -> VBP
# Synonyms: {'ar', 'cost', 'are', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
#
#
#
# Sentence 28 : The power of imagination allows us to create and innovate.
#
# allows -> NNS
# Synonyms: {'provide', 'reserve', 'tolerate', 'allow', 'leave', 'set_aside', 'appropriate', 'take_into_account', 'let', 'admit', 'permit', 'allow_for', 'countenance', 'give_up', 'earmark', 'grant'}
# Antonyms: {'deny', 'forbid', 'disallow', 'prevent'}
#
# create -> VBP
# Synonyms: {'create', 'produce', 'make'}
# Antonyms: None
#
# innovate -> NN
# Synonyms: {'introduce', 'innovate'}
# Antonyms: None
#
#
#
#
# Sentence 29 : Developing a strong work ethic is important for achieving your goals.
#
# Developing -> VBG
# Synonyms: {'educate', 'development', 'arise', 'germinate', 'acquire', 'recrudesce', 'spring_up', 'train', 'modernise', 'develop', 'underdeveloped', 'modernize', 'rise', 'formulate', 'originate', 'developing', 'uprise', 'grow', 'build_up', 'break', 'get', 'produce', 'prepare', 'evolve', 'explicate', 'make_grow'}
# Antonyms: None
#
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# achieving -> VBG
# Synonyms: {'accomplish', 'achieve', 'attain', 'reach'}
# Antonyms: None
#
#
#
#
# Sentence 30 : Education is the key to unlocking your full potential.
# is -> VBZ
# Synonyms: {'cost', 'constitute', 'embody', 'comprise', 'personify', 'make_up', 'follow', 'equal', 'be', 'exist', 'live', 'represent'}
# Antonyms: {'differ'}
#
# unlocking -> VBG
# Synonyms: {'unlock'}
# Antonyms: {'lock'}
